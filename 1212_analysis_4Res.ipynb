# %%
import analysis_nmda as ana
import importlib
importlib.reload(ana)
# %matplotlib inline

# %%
ana.k_integrate_1128()

# %%
ana.rates_ai2015(2,15,28)

# %%
ana.integrate()
#ana.integrate_sfn2014()
#ana.integrate_Data50()

# %%
ana.magSyn_Data50(2,15,28)
#ana.plot_CC_bar()

# %%
ana.cc_ai2015(2,15,28)
#G1で2000	G15で3969	G38で5033

# %%
ana.figures_ai2015(2,15,28)
